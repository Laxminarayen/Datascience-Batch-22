# %%
# !unzip playground-series-s4e2.zip
# Out:
# Archive:  playground-series-s4e2.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")
original_data = pd.read_csv("ObesityDataSet.csv")

# %% [markdown]
# The attributes related with eating habits are: Frequent consumption of high caloric food (FAVC), Frequency of consumption of vegetables (FCVC), Number of main meals (NCP), Consumption of food between meals (CAEC), Consumption of water daily (CH20), and Consumption of alcohol (CALC). The attributes related with the physical condition are: Calories consumption monitoring (SCC), Physical activity frequency (FAF), Time using technology devices (TUE), Transportation used (MTRANS)

# %%
df.head()
# Out:
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# ...

# %%
df.drop('id', axis = 1, inplace= True)

# %%
df = pd.concat([df,original_data],ignore_index = True)
df.head()
# Out:
#    Gender        Age    Height      Weight family_history_with_overweight  \
# 0    Male  24.443011  1.699998   81.669950                            yes
# 1  Female  18.000000  1.560000   57.000000                            yes
# 2  Female  18.000000  1.711460   50.165754                            yes
# 3  Female  20.952737  1.710730  131.274851                            yes
# 4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# ...

# %%
df_test
# Out:
#           id  Gender        Age    Height      Weight  \
# 0      20758    Male  26.899886  1.848294  120.644178
# 1      20759  Female  21.000000  1.600000   66.000000
# 2      20760  Female  26.000000  1.643355  111.600553
# 3      20761    Male  20.979254  1.553127  103.669116
# 4      20762  Female  26.000000  1.627396  104.835346
# ...      ...     ...        ...       ...         ...
# 13835  34593    Male  23.327836  1.721384   78.030383
# 13836  34594  Female  29.000000  1.590000   62.000000
# 13837  34595  Female  22.935612  1.585547   44.376637
# 13838  34596    Male  21.000000  1.620000   53.000000
# 13839  34597    Male  26.490926  1.812259  120.980508
#
#       family_history_with_overweight FAVC      FCVC       NCP        CAEC  \
# 0                                yes  yes  2.938616  3.000000   Sometimes
# 1                                yes  yes  2.000000  1.000000   Sometimes
# 2                                yes  yes  3.000000  3.000000   Sometimes
# ...

# %%
#df['column'] = 'Train'
#df_test['column'] = "Test"

# %%
#df = pd.concat([df,df_test])

# %%
#During Train Time!
#train = df.loc[df['column'] == 'Train'].copy()
#test = df.loc[df['column'] == 'Test'].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22869 entries, 0 to 22868
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          22869 non-null  object
#  1   Age                             22869 non-null  float64
#  2   Height                          22869 non-null  float64
#  3   Weight                          22869 non-null  float64
#  4   family_history_with_overweight  22869 non-null  object
#  5   FAVC                            22869 non-null  object
#  6   FCVC                            22869 non-null  float64
#  7   NCP                             22869 non-null  float64
#  8   CAEC                            22869 non-null  object
#  9   SMOKE                           22869 non-null  object
#  10  CH2O                            22869 non-null  float64
#  11  SCC                             22869 non-null  object
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13840 entries, 0 to 13839
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              13840 non-null  int64
#  1   Gender                          13840 non-null  object
#  2   Age                             13840 non-null  float64
#  3   Height                          13840 non-null  float64
#  4   Weight                          13840 non-null  float64
#  5   family_history_with_overweight  13840 non-null  object
#  6   FAVC                            13840 non-null  object
#  7   FCVC                            13840 non-null  float64
#  8   NCP                             13840 non-null  float64
#  9   CAEC                            13840 non-null  object
#  10  SMOKE                           13840 non-null  object
#  11  CH2O                            13840 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# id                                0
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['BMI'] = (df['Weight'] / (df['Height'] * df['Height']))

# %%
df_test['BMI'] = (df_test['Weight'] / (df_test['Height'] * df_test['Height']))

# %%
df.drop(columns = ['Height','Weight'],inplace = True)
df_test.drop(columns = ['Height','Weight'],inplace = True)

# %%
df.head()
# Out:
#    Gender        Age    Height      Weight family_history_with_overweight  \
# 0    Male  24.443011  1.699998   81.669950                            yes
# 1  Female  18.000000  1.560000   57.000000                            yes
# 2  Female  18.000000  1.711460   50.165754                            yes
# 3  Female  20.952737  1.710730  131.274851                            yes
# 4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# ...

# %%
df_test.head()
# Out:
#       id  Gender        Age    Height      Weight  \
# 0  20758    Male  26.899886  1.848294  120.644178
# 1  20759  Female  21.000000  1.600000   66.000000
# 2  20760  Female  26.000000  1.643355  111.600553
# 3  20761    Male  20.979254  1.553127  103.669116
# 4  20762  Female  26.000000  1.627396  104.835346
#
#   family_history_with_overweight FAVC      FCVC       NCP       CAEC SMOKE  \
# 0                            yes  yes  2.938616  3.000000  Sometimes    no
# 1                            yes  yes  2.000000  1.000000  Sometimes    no
# 2                            yes  yes  3.000000  3.000000  Sometimes    no
# 3                            yes  yes  2.000000  2.977909  Sometimes    no
# 4                            yes  yes  3.000000  3.000000  Sometimes    no
#
#        CH2O SCC       FAF       TUE       CALC                 MTRANS
# 0  2.825629  no  0.855400  0.000000  Sometimes  Public_Transportation
# 1  3.000000  no  1.000000  0.000000  Sometimes  Public_Transportation
# ...

# %%
num_cols =[]
cat_cols = []
for col in df.columns:
  if df[col].dtype=='object':
    cat_cols.append(col)
  else:
    num_cols.append(col)

# %%
print("Cat columns: ",cat_cols)
print("Numerical columns: ",num_cols)
# Out:
# Cat columns:  ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS', 'NObeyesdad']
# Numerical columns:  ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']

# %%
target_col = 'NObeyesdad'
cat_cols.remove(target_col)
df.NObeyesdad.value_counts()
# Out:
# Obesity_Type_III       4370
# Obesity_Type_II        3545
# Normal_Weight          3364
# Obesity_Type_I         3261
# Overweight_Level_II    2812
# Insufficient_Weight    2790
# Overweight_Level_I     2703
# Name: NObeyesdad, dtype: int64

# %%
df[cat_cols].nunique()
# Out:
# Gender                            2
# family_history_with_overweight    2
# FAVC                              2
# CAEC                              4
# SMOKE                             2
# SCC                               2
# CALC                              4
# MTRANS                            5
# dtype: int64

# %%
for col_name in num_cols:
    print(col_name)
    q1 = df[col_name].quantile(0.25)
    q3 = df[col_name].quantile(0.75)
    iqr = q3-q1
    print("IQR", iqr)
    print("Q1", q1)
    print("Q3", q3)
    low = q1-(1.5*iqr)
    upper = q3+(1.5*iqr)
    print("the lower value: ",low )
    print("the upper value: ", upper)
    print('-'*100)
# Out:
# Age
# IQR 6.0
# Q1 20.0
# Q3 26.0
# the lower value:  11.0
# the upper value:  35.0
# ----------------------------------------------------------------------------------------------------
# Height
# IQR 0.13117299999999998
# Q1 1.631856
# Q3 1.763029
# the lower value:  1.4350965
# the upper value:  1.9597885
# ----------------------------------------------------------------------------------------------------
# Weight
# IQR 45.53120800000001
# Q1 66.0
# Q3 111.531208
# the lower value:  -2.296812000000017
# the upper value:  179.82802000000004
# ----------------------------------------------------------------------------------------------------
# FCVC
# IQR 1.0
# Q1 2.0
# Q3 3.0
# the lower value:  0.5
# the upper value:  4.5
# ----------------------------------------------------------------------------------------------------
# NCP
# IQR 0.0
# Q1 3.0
# Q3 3.0
# the lower value:  3.0
# the upper value:  3.0
# ...

# %%
df['Age'].min()
# Out:
# 14.0

# %%
df['Age'].max()
# Out:
# 61.0

# %%
df['CH2O'].min()
# Out:
# 1.0

# %%
df['CH2O'].max()
# Out:
# 3.0

# %%
df['NCP'].min()
# Out:
# 1.0

# %%
df['NCP'].max()
# Out:
# 4.0

# %%
#look for Logical inconsitencies alogn with Outliers - Impute domain Knowledge too!

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

df_test[num_cols] = scaler.transform(df_test[num_cols])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for cols in cat_cols:
  encoded_cols = le.fit_transform(df[cols])
  test_encoded_cols = le.transform(df_test[cols])
  df[cols] = encoded_cols
  df_test[cols] = test_encoded_cols

# %%
target_encoder = LabelEncoder()
encoded_target = target_encoder.fit_transform(df['NObeyesdad'])
df.NObeyesdad = encoded_target

# %%
y = df.NObeyesdad.copy()
X = df.drop(['NObeyesdad'], axis =1 ).copy()

# %%
# !pip install lazypredict

# %%
from lazypredict.Supervised import LazyClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
clf = LazyClassifier(verbose = 0, predictions = True)
models, predictions = clf.fit(X_train, X_val, y_train, y_val )
# Out:
#   7%|▋         | 2/29 [00:03<00:41,  1.53s/it]/usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.90               0.89    None      0.90
# XGBClassifier                      0.90               0.89    None      0.90
# RandomForestClassifier             0.89               0.88    None      0.89
# BaggingClassifier                  0.88               0.87    None      0.88
# ExtraTreesClassifier               0.87               0.86    None      0.87
# SVC                                0.86               0.85    None      0.86
# LogisticRegression                 0.85               0.84    None      0.85
# DecisionTreeClassifier             0.84               0.82    None      0.84
# LinearDiscriminantAnalysis         0.82               0.81    None      0.82
# NuSVC                              0.81               0.79    None      0.81
# ExtraTreeClassifier                0.75               0.73    None      0.75
# ...

# %%
#Without BMI Test
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 1)
clf = LazyClassifier(verbose = 0, predictions = True)
models, predictions = clf.fit(X_train, X_val, y_train, y_val)
# Out:
#   7%|▋         | 2/29 [00:05<01:15,  2.81s/it]/usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.91               0.91    None      0.91
# XGBClassifier                      0.91               0.90    None      0.91
# RandomForestClassifier             0.90               0.89    None      0.90
# BaggingClassifier                  0.89               0.88    None      0.89
# ExtraTreesClassifier               0.88               0.87    None      0.88
# SVC                                0.87               0.85    None      0.87
# LogisticRegression                 0.86               0.85    None      0.86
# DecisionTreeClassifier             0.85               0.84    None      0.85
# LinearDiscriminantAnalysis         0.81               0.80    None      0.81
# NuSVC                              0.80               0.78    None      0.80
# ExtraTreeClassifier                0.78               0.76    None      0.78
# ...

# %%
import lightgbm as lgb

# %%
params = {
    'objective': 'multiclass',
    'metric':'multi_logloss',
    'num_class':7,
    'lambda_l1': 0.01,
    'lambda_l2':0.0402,
    'learning_rate':0.03,
    'max_depth':10,
    'n_estimators':500,
    'boosting_type':'gbdt',
    'min_child_samples':26,
    'subsample':0.9536,
    'colsample_bytree':0.41,
    'random_state': 42,
    'verbose':0
}

# %%
lbc = lgb.LGBMClassifier(**params)
lbc.fit(X_train, y_train)

# %%
accuracy = float(lbc.score(X_val,y_val))
# Out:
# [LightGBM] [Warning] lambda_l2 is set=0.0402, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0402
# [LightGBM] [Warning] lambda_l1 is set=0.01, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.01
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).

# %%
print(accuracy)
# Out:
# 0.9152987524622456

# %%
test = df_test.drop('id',axis = 1).copy()
test_y = lbc.predict(test)
# Out:
# [LightGBM] [Warning] lambda_l2 is set=0.0402, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0402
# [LightGBM] [Warning] lambda_l1 is set=0.01, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.01
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).

# %%
submission = pd.DataFrame({'id':df_test['id'],'NObeyesdad':test_y})

# %%
submission.NObeyesdad = target_encoder.inverse_transform(submission.NObeyesdad)

# %%
submission
# Out:
#           id           NObeyesdad
# 0      20758      Obesity_Type_II
# 1      20759   Overweight_Level_I
# 2      20760     Obesity_Type_III
# 3      20761       Obesity_Type_I
# 4      20762     Obesity_Type_III
# ...      ...                  ...
# 13835  34593  Overweight_Level_II
# 13836  34594   Overweight_Level_I
# 13837  34595  Insufficient_Weight
# 13838  34596        Normal_Weight
# 13839  34597      Obesity_Type_II
#
# [13840 rows x 2 columns]

# %%
submission.to_csv("submissionLGBM.csv",index = False)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
import numpy as np
params = {

    'lambda_l1': list(np.arange(0,0.2,0.01)),
    'lambda_l2':list(np.arange(0,0.3,0.01)),
    'learning_rate':[0.01,0.001,0.0001,0.1],
    'max_depth':[10,20,30,40,50],
    'n_estimators':list(range(100,600,50)),
}
params_fixed = {
    'objective': 'multiclass',
    'metric':'multi_logloss',
    'num_class':7,
    'boosting_type':'gbdt',
    'subsample':0.9536,
    'colsample_bytree':0.41,
    'random_state': 42,
    'verbose':0,
    'min_data_in_leaf':10
}

# %%
import lightgbm as lgb
LGMTune = lgb.LGBMClassifier(**params_fixed)

# %%
LGMTuned = RandomizedSearchCV(LGMTune, params, cv=3,n_iter=10)

# %%
LGMTuned.fit(X_train,y_train)

# %%
print(LGMTuned.best_estimator_)
# Out:
# LGBMClassifier(colsample_bytree=0.41, lambda_l1=0.06, lambda_l2=0.17,
#                max_depth=40, metric='multi_logloss', min_data_in_leaf=10,
#                n_estimators=200, num_class=7, objective='multiclass',
#                random_state=42, subsample=0.9536, verbose=0)

# %%
print(LGMTuned.best_score_)
# Out:
# 0.9104289778945064

# %%
print(LGMTuned.best_params_)
# Out:
# {'n_estimators': 200, 'max_depth': 40, 'learning_rate': 0.1, 'lambda_l2': 0.17, 'lambda_l1': 0.06}

# %%
params_fixed = {
    'objective': 'multiclass',
    'metric':'multi_logloss',
    'num_class':7,
    'boosting_type':'gbdt',
    'subsample':0.9536,
    'colsample_bytree':0.41,
    'random_state': 42,
    'verbose':0,
    'min_data_in_leaf':10,
    'n_estimators': 200,
    'max_depth': 40,
    'learning_rate': 0.1,
    'lambda_l2': 0.17,
    'lambda_l1': 0.06
}

# %%
import lightgbm as lgb
LGMTuned = lgb.LGBMClassifier(**params_fixed)
LGMTuned.fit(X_train,y_train)
pred_lgb = LGMTuned.predict(X_val)
pred_proba =LGMTuned.predict_proba(X_val)

# %%
LGMTuned.score(X_val,y_val)

# %%
# !pip install optuna

# %%
import optuna

# %%
def objective(trail):
  thresholds = {}
  for i in range(num_classes):
    thresholds[f'threshold_{i}'] = trail.suggest_uniform(f'threshold_{i}',0.0,1.0)

  y_pred = apply_thresholds(pred_proba,thresholds)

  accuracy = accuracy_score(y_val, y_pred)
  return accuracy

def apply_thresholds(y_proba, thresholds):
  y_pred_labels = np.argmax(y_proba, axis =1)
  for i in range(y_proba.shape[1]):
    y_pred_labels[y_proba[:,i] > thresholds[f'threshold_{i}']] = i
  return y_pred_labels

# %%
[0.7, 0.3] != 1 = 0
[0-1, 0-1, 0-1]

# %%
num_classes = 7
pred_proba = pred_proba
y_val = y_val

study = optuna.create_study(direction='maximize')
study.optimize(objective,n_trials=100)

best_thresholds = study.best_params
print("Best thresholds:", best_thresholds)

# %%
thresholds= {'threshold_0': 0.8998640201640411, 'threshold_1': 0.8895200698519597, 'threshold_2': 0.24583928304442698, 'threshold_3': 0.6430045448790183, 'threshold_4': 0.2803967700841142, 'threshold_5': 0.7652218341287134, 'threshold_6': 0.6783888156402386}

# %%
test_label = LGMTuned.predict_proba(df_test.drop(columns = ['id']))
test_label = apply_thresholds(test_label,thresholds)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] lambda_l2 is set=0.17, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.17
# [LightGBM] [Warning] lambda_l1 is set=0.06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).

# %%
pred = target_encoder.inverse_transform(test_label)
submission = pd.DataFrame({'id': df_test.id,'NObeyesdad':pred})
submission.to_csv("Submission_tuned_random.csv",index = False)
